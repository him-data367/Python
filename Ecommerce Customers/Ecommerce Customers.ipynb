# %% [markdown]
# # Ecommerce Customers

# %% [markdown]
# ##### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Import dataset

# %%
data =pd.read_csv('D:/libraries/Ecommerce Customers/Ecommerce Customers.csv')

# %% [markdown]
# ##### First 10 values

# %%
data.head(10)
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
# 5         alvareznancy@lucas.biz
# 6          katherine20@yahoo.com
# 7             awatkins@yahoo.com
# 8    vchurch@walter-martinez.com
# 9               bonnie69@lin.biz
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# 5  645 Martha Park Apt. 611\nJeffreychester, MN 6...       FloralWhite
# 6  68388 Reyes Lights Suite 692\nJosephbury, WV 9...     DarkSlateBlue
# ...

# %%
# shape of the dataset
data.shape
# Out:
# (500, 8)

# %%
# columns of dateset
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
# unique values in the dataset
data.nunique()
# there are only 138 values in the avatar columns
# Out:
# Email                   500
# Address                 500
# Avatar                  138
# Avg. Session Length     500
# Time on App             500
# Time on Website         500
# Length of Membership    500
# Yearly Amount Spent     500
# dtype: int64

# %% [markdown]
# #### Checking null values

# %%
data.isna().sum()
# there are no missing values in the data
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %% [markdown]
# #### Checking duplicates

# %%
data.duplicated().sum()
# there are no duplicates value
# Out:
# 0

# %%
# data types of columns
data.dtypes
# Out:
# Email                    object
# Address                  object
# Avatar                   object
# Avg. Session Length     float64
# Time on App             float64
# Time on Website         float64
# Length of Membership    float64
# Yearly Amount Spent     float64
# dtype: object

# %%
# numericals value of the data
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
# chart between the time on website and yearly amount spend
plt.figure(figsize=(14,6))
sns.jointplot(data['Time on Website'],data['Yearly Amount Spent'],data=data,color='blue',alpha=0.75,edgecolor='black')

plt.title('Time on website Vs Yearly amount spent',fontweight='bold',size=20, x=5)
#plt.text(5,19,'Relation Between time on website and yearly amount spend',fontfamily='serif',color='#4a4a4a', fontweight='bold',fontsize=12)
# Out:
# Text(5, 1, 'Time on website Vs Yearly amount spent')

# %% [markdown]
# ##### Relation graph between all the columns

# %%
sns.pairplot(data=data)

# %% [markdown]
# ##### Relation between time on app and yearly amount spend

# %%
sns.jointplot(data['Time on App'],data['Yearly Amount Spent'],data=data,edgecolor='black',cmap='summer',alpha=0.75,color='green')

# %% [markdown]
# ##### Relation Between Time on app and length of membership

# %%
plt.style.use('seaborn')
sns.jointplot(x=data['Time on App'],y=data['Length of Membership'],data=data,color='red',alpha=0.75,edgecolor='black')

# %%
# heatmap of all the columns
plt.figure(figsize=(14,6))
sns.heatmap(data.corr(),annot=True)
plt.title('Heatmap of dataset',fontsize=20)
# Out:
# Text(0.5, 1, 'Heatmap of dataset')

# %% [markdown]
# ##### pivot table of the dataset

# %%
address = pd.pivot_table(data,values=['Yearly Amount Spent','Time on App','Length of Membership','Time on Website'],index='Address',aggfunc=max)
address=address.sort_values(by='Yearly Amount Spent',ascending=False)
address.style.background_gradient(cmap='Pastel2')
# Out:
# <style  type="text/css" >
#     #T_afa48dfe_c003_11ed_a788_14feb59b51carow0_col0 {
#             background-color:  #f1e2cc;
#             color:  #000000;
#         }    #T_afa48dfe_c003_11ed_a788_14feb59b51carow0_col1 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_afa48dfe_c003_11ed_a788_14feb59b51carow0_col2 {
#             background-color:  #e6f5c9;
#             color:  #000000;
#         }    #T_afa48dfe_c003_11ed_a788_14feb59b51carow0_col3 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_afa48dfe_c003_11ed_a788_14feb59b51carow1_col0 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_afa48dfe_c003_11ed_a788_14feb59b51carow1_col1 {
#             background-color:  #e6f5c9;
#             color:  #000000;
#         }    #T_afa48dfe_c003_11ed_a788_14feb59b51carow1_col2 {
#             background-color:  #b3e2cd;
#             color:  #000000;
# ...

# %% [markdown]
# ##### trend line for the yearly spend money with membership

# %%
plt.figure(figsize=(14,7))
plt.scatter(data['Time on App'],data['Yearly Amount Spent'],cmap='summer',alpha=0.75,edgecolor='black',linewidth=1,c=data['Length of Membership'])
cbar=plt.colorbar()
cbar.set_label('Length on Membership')
plt.title('Yearly Amount Spent vs Time on App',size=20)
# Out:
# Text(0.5, 1.0, 'Yearly Amount Spent vs Time on App')

# %%
# distplot of  yearly spend money

plt.figure(figsize=(14,7))

sns.distplot(data['Yearly Amount Spent'],color='green')
sns.distplot(data['Yearly Amount Spent'],hist=False,color='black')
plt.title('Distribution of yearly amount',size=20)
# Out:
# Text(0.5, 1.0, 'Distribution of yearly amount')

# %% [markdown]
# ##### prediction of data

# %%
x=data[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
y =data['Yearly Amount Spent']
#import library for prediction
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=110)
#import library for training
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([ 2.51580043e+01,  3.91894965e+01, -3.49369698e-02,  6.21761670e+01])

# %%
#prediction
pred =lm.predict(x_test)
plt.scatter(y_test,pred,edgecolor='black',alpha=0.75,linewidth=1)
plt.title('Prediction',size=20)
plt.xlabel('Y Test',size=12)
plt.ylabel('Predicted y',size=12)
plt.show()

# %%
# error
from sklearn import metrics
print('Mean Absolute error:',metrics.mean_absolute_error(y_test,pred))
print('Mean squared error:',metrics.mean_squared_error(y_test,pred))
print('Root mean squared error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# Mean Absolute error: 8.298993401961665
# Mean squared error: 106.20161075414053
# Root mean squared error: 10.305416573537459

# %%
# coeffecient of data
coffecient = pd.DataFrame(lm.coef_,x.columns)
coffecient.columns =['Coffecient']
coffecient
# Out:
#                       Coffecient
# Avg. Session Length    25.158004
# Time on App            39.189497
# Time on Website        -0.034937
# Length of Membership   62.176167
