# %% [markdown]
# # The whether dataset

# %% [markdown]
# Weather data provides information about the weather and climate of a region. It tracks patterns and predicts trends.
#
# Weather refers to short-term atmospheric conditions of a region and can include indicators such as minimum /maximum temperature, humidity, or wind speed. Climate is the weather of a region averaged over a long period of time. Climate data covers details such as seasonal average temperatures or decade-long patterns of rains and contributes to climate prediction.

# %%
import pandas as pd

# %%
data =pd.read_csv(r'C:/Users/211BN/Downloads/EXCEL/tableau/Weather Data.csv')
#r is used to remove the unicode error

# %%
#head is used to display the top 5 record of the data 
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#shape is used to know the dimension of the data
data.shape
# Out:
# (8784, 8)

# %%
#It is used to show the columns of the data
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
#index provide the dataframe of the data
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
# dtypes is used to genrate the data of each columns
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# ndim is used to generate the dimension of the data
data.ndim
# Out:
# 2

# %%
#to see the unique value of the columns you have to add the columns after the data
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
#(nunique) is used to display the data of each columns or full data(it will count the data present in the given data)
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
# count is used the value in the data
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
#to count the columns data used value_count()
#normaize is used for the define total percentage of the columns 100 is used for display the number after two digits
100*data['Weather'].value_counts(normalize=True).head()
# Out:
# Mainly Clear     23.975410
# Mostly Cloudy    23.554189
# Cloudy           19.672131
# Clear            15.095628
# Snow              4.439891
# Name: Weather, dtype: float64

# %%
# info used to all the information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 480.4+ KB

# %%
#It will give the aggreating function of the given data
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
#find the given unique values in the fiven data like Wind Speed_km/h
#nunique is used to find all unique values in the data 
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
# we are then find and filter the wind_speed if whether is clear
data.head()
# filtering
# this will give the boolean value
'''to see all the values in the given command use 70 is used to display 
the columns but there are many columns in it so 
to display full value used 70 as the end columns index
'''
pd.set_option('display.max_rows',70)
data['Weather'].str.contains('Clear')#1 method
#data[data['Weather']=='Clear']#2 method it will give the dataframe to display on bool use method 1
data[data.Weather=='Clear']# method 3 to view bool type init used data.Weather=='Clear'
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# groupby used to group the whole columns into one
Weather=data.groupby('Weather')
# to get the particular data from the weather used get_group method
Weather.get_group('Clear')# Or you can used the formula as data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# filter the data where wind_speed is greater than 4
data[data['Wind Speed_km/h']==4].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 96   1/5/2012 0:00    -8.8             -11.7         79                4
# 101  1/5/2012 5:00    -7.0              -9.5         82                4
# 146  1/7/2012 2:00    -8.1             -11.1         79                4
#
#      Visibility_km  Press_kPa Weather
# 0              8.0     101.24     Fog
# 1              8.0     101.24     Fog
# 96             9.7     100.32    Snow
# 101            4.0     100.19    Snow
# 146           19.3     100.15  Cloudy

# %%
# find the null data present in the data isnull(bool type) not null() or 
# 0 means no_null
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# rename the values in the given data use dictionary to replace
data.rename(columns={'Weather':'Weather_condition'},inplace=True)
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.head()
# we will find the avg in the visibilty columns in the data but libraies have no avg func use mean
data['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %%
# to find different aggreate fucntion used  agg func in the command
data['Press_kPa'].agg(['mean','sum','median','min','max','std','var'])
# use other columns at the place of press_kPa for other values
# Out:
# mean         101.051623
# sum       887637.460000
# median       101.070000
# min           97.520000
# max          103.650000
# std            0.844005
# var            0.712344
# Name: Press_kPa, dtype: float64

# %%
# we will check if in weather there are any source if show is seeing
data['Weather_condition'].str.contains('Snow').sum()
# we have seen the snow at 583 times in the whole season
# Out:
# 583

# %%
# or used simple filter by comparing
data[data['Weather_condition']=='Snow'].head()
# To see more values in the data fill the number inside the head
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   1/3/2012 7:00   -14.0             -19.5         63               19
# 84  1/4/2012 12:00   -13.7             -21.7         51               11
# 86  1/4/2012 14:00   -11.3             -19.0         53                7
# 87  1/4/2012 15:00   -10.2             -16.3         61               11
# 88  1/4/2012 16:00    -9.4             -15.5         61               13
#
#     Visibility_km  Press_kPa Weather_condition
# 55           25.0     100.95              Snow
# 84           24.1     101.25              Snow
# 86           19.3     100.97              Snow
# 87            9.7     100.89              Snow
# 88           19.3     100.79              Snow

# %%
# wind_speed is more than 24 and visibility is 25
data[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==25)].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0         79               30
# 24   1/2/2012 0:00     5.2               1.5         77               35
# 25   1/2/2012 1:00     4.6               0.0         72               39
# 26   1/2/2012 2:00     3.9              -0.9         71               32
# 27   1/2/2012 3:00     3.7              -1.5         69               33
#
#     Visibility_km  Press_kPa Weather_condition
# 23           25.0      99.31            Cloudy
# 24           25.0      99.26      Rain Showers
# 25           25.0      99.26            Cloudy
# 26           25.0      99.26     Mostly Cloudy
# 27           25.0      99.30     Mostly Cloudy

# %%
# aggregate function to find the mean value of each columns against 'Weather_condition'
# method 1
data.groupby(['Weather_condition'])[['Temp_C','Dew Point Temp_C','Rel Hum_%','Wind Speed_km/h','Visibility_km','Press_kPa']].mean().reset_index()
# method 2 in this method weather_condition used as index_col
data.groupby(['Weather_condition']).mean().head()
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_condition
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          Wind Speed_km/h  Visibility_km   Press_kPa
# Weather_condition
# Clear                          10.557315      30.153243  101.587443
# Cloudy                         16.127315      26.625752  100.911441
# Drizzle                        16.097561      17.931707  100.435366
# Drizzle,Fog                    11.862500       5.257500  100.786625
# Drizzle,Ice Pellets,Fog        20.000000       4.000000  100.790000

# %%
# used agg function weather-conition
data.groupby(['Weather_condition']).max().head()
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_condition
# Clear                      9/9/2012 5:00    32.8              20.4         99
# Cloudy                    9/9/2012 23:00    30.5              22.6         99
# Drizzle                   9/30/2012 3:00    18.8              17.7         96
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather_condition
# Clear                                 33           48.3     103.63
# Cloudy                                54           48.3     103.65
# Drizzle                               30           25.0     101.56
# Drizzle,Fog                           28            9.7     102.07
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
data.groupby(['Weather_condition']).min().head()
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_condition
# Clear                     1/11/2012 1:00   -23.3             -28.5         20
# Cloudy                    1/1/2012 17:00   -21.4             -26.8         18
# Drizzle                  1/23/2012 21:00     1.1              -0.2         74
# Drizzle,Fog              1/23/2012 20:00     0.0              -1.6         85
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather_condition
# Clear                                  0           11.3      99.52
# Cloudy                                 0           11.3      98.39
# Drizzle                                0            6.4      97.84
# Drizzle,Fog                            0            1.0      98.65
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
# check if fog is present in the weather_condition
data['Weather_condition'].str.contains('Fog').sum()
# Out:
# 426

# %%
data['Weather_condition'].str.contains('Rain Showers').sum()
# Out:
# 212

# %%
data['Weather_condition'].str.contains('Mostly Cloudy').sum()
# Out:
# 2069

# %%
# weather_condition is clear and visibility is 40
data[(data['Weather_condition']=='Clear')| (data['Visibility_km']>40)].head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
#
#      Visibility_km  Press_kPa Weather_condition
# 67            25.0     101.74             Clear
# 106           48.3     100.45      Mainly Clear
# 107           48.3     100.41      Mainly Clear
# 108           48.3     100.38      Mainly Clear
# 109           48.3     100.40      Mainly Clear

# %%
# weather condition is clear and humidity is greater than 50 or visibilty is above 40
data[(data['Weather_condition']=='Clear') & ((data['Rel Hum_%']>50) | (data['Visibility_km']> 40))]
# the rows are 1220 and 8columns
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# 241     1/11/2012 1:00   -10.7             -17.8         56               17
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
